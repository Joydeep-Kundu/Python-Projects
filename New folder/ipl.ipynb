# %%
import pandas as pd

# %%
df=pd.read_csv('IPLIMB381IPL2013.csv')
df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df.shape
# Out:
# (130, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %%
df.head(20)
# Out:
#     Sl.NO.      PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0        1      Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1        2     Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2        3      Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3        4        Ashwin, R    1     IND   CSK       Bowler     284      31
# 4        5     Badrinath, S    2     IND   CSK      Batsman      63       0
# 5        6       Bailey, GJ    2     AUS   CSK      Batsman       0       0
# 6        7        Balaji, L    2     IND  CSK+       Bowler      51      27
# 7        8    Bollinger, DE    2     AUS   CSK       Bowler      54      50
# 8        9         Botha, J    2      SA    RR   Allrounder      83      17
# 9       10      Boucher, MV    2      SA  RCB+    W. Keeper    5515       1
# 10      11        Bravo, DJ    2      WI   MI+   Allrounder    2200      86
# ...

# %%
df.transpose()
# Out:
#                        0             1            2          3    \
# Sl.NO.                   1             2            3          4
# PLAYER NAME    Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R
# AGE                      2             2            2          1
# COUNTRY                 SA           BAN          IND        IND
# TEAM                  KXIP           RCB          KKR        CSK
# PLAYING ROLE    Allrounder        Bowler       Bowler     Bowler
# T-RUNS                   0           214          571        284
# T-WKTS                   0            18           58         31
# ODI-RUNS-S               0           657         1269        241
# ODI-SR-B               0.0         71.41        80.62      84.56
# ODI-WKTS                 0           185          288         51
# ODI-SR-BL              0.0          37.6         32.9       36.8
# CAPTAINCY EXP            0             0            0          0
# ...

# %%
df.head(20).transpose()
# Out:
#                         0             1            2          3   \
# Sl.NO.                   1             2            3          4
# PLAYER NAME    Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R
# AGE                      2             2            2          1
# COUNTRY                 SA           BAN          IND        IND
# TEAM                  KXIP           RCB          KKR        CSK
# PLAYING ROLE    Allrounder        Bowler       Bowler     Bowler
# T-RUNS                   0           214          571        284
# T-WKTS                   0            18           58         31
# ODI-RUNS-S               0           657         1269        241
# ODI-SR-B               0.0         71.41        80.62      84.56
# ODI-WKTS                 0           185          288         51
# ODI-SR-BL              0.0          37.6         32.9       36.8
# CAPTAINCY EXP            0             0            0          0
# ...

# %%
df.iloc[120:126]
# Out:
#      Sl.NO.     PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 120     121     Vettori, DL    2      NZ   DD+   Allrounder    4486     359
# 121     122  Vinay Kumar, R    2     IND  RCB+       Bowler      11       1
# 122     123       Warne, SK    3     AUS    RR       Bowler    3154     708
# 123     124      Warner, DA    1     AUS    DD      Batsman     483       2
# 124     125       White, CL    2     AUS  RCB+      Batsman     146       5
# 125     126       Yadav, AS    2     IND    DC      Batsman       0       0
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 120        2105     81.93  ...  107.08       2     878    28   31.36   6.81
# 121          43     43.87  ...  104.83       5    1664    61   27.28   8.24
# 122        1018     72.04  ...   92.52       6    1447    57   25.39   7.27
# 123         876     85.79  ...  135.76      44       0     0    0.00   0.00
# ...

# %%
df.tail(10)
# Out:
#      Sl.NO.     PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 120     121     Vettori, DL    2      NZ    DD+   Allrounder    4486     359
# 121     122  Vinay Kumar, R    2     IND   RCB+       Bowler      11       1
# 122     123       Warne, SK    3     AUS     RR       Bowler    3154     708
# 123     124      Warner, DA    1     AUS     DD      Batsman     483       2
# 124     125       White, CL    2     AUS   RCB+      Batsman     146       5
# 125     126       Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127     Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128    Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129     Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130      Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# ...

# %%
df[-10:]
# Out:
#      Sl.NO.     PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 120     121     Vettori, DL    2      NZ    DD+   Allrounder    4486     359
# 121     122  Vinay Kumar, R    2     IND   RCB+       Bowler      11       1
# 122     123       Warne, SK    3     AUS     RR       Bowler    3154     708
# 123     124      Warner, DA    1     AUS     DD      Batsman     483       2
# 124     125       White, CL    2     AUS   RCB+      Batsman     146       5
# 125     126       Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127     Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128    Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129     Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130      Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# ...

# %%
df[['PLAYER NAME','COUNTRY']][99:]
# Out:
#           PLAYER NAME COUNTRY
# 99       Shoaib Malik     PAK
# 100        Silva, LPC      SL
# 101         Singh, RP     IND
# 102         Smith, DR      WI
# 103         Smith, GC      SA
# 104     Sohail Tanvir     PAK
# 105      Sreesanth, S     IND
# 106         Steyn, DW      SA
# 107        Styris, SB      NZ
# 108        Symonds, A     AUS
# 109          Taibu, T     ZIM
# 110      Taylor, LRPL      NZ
# 111     Tendulkar, SR     IND
# 112        Tiwary, MK     IND
# 113        Tiwary, SS     IND
# 114          Tyagi, S     IND
# 115          Umar Gul     PAK
# 116       Uthappa, RV     IND
# 117       Vaas, WPUJC      SL
# 118     Van der Merwe      SA
# 119  Venugopal Rao, Y     IND
# 120       Vettori, DL      NZ
# 121    Vinay Kumar, R     IND
# 122         Warne, SK     AUS
# 123        Warner, DA     AUS
# 124         White, CL     AUS
# 125         Yadav, AS     IND
# 126       Younis Khan     PAK
# 127      Yuvraj Singh     IND
# 128       Zaheer Khan     IND
# ...

# %%
df.iloc[10:21,2:8]
# Out:
#     AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS
# 10    2      WI   MI+   Allrounder    2200      86
# 11    3      WI   RCB      Batsman    9918       9
# 12    1     IND  KXIP   Allrounder       5       3
# 13    2      SA   DD+    W. Keeper    5457       2
# 14    2     IND   MI+      Batsman       0       0
# 15    2     IND   CSK    W. Keeper    3509       0
# 16    2      SL   DD+   Allrounder    4722      32
# 17    2     IND  KKR+       Bowler       0       0
# 18    3     IND  RCB+      Batsman   13288       1
# 19    2      SA   MI+      Batsman     654      11
# 20    2      WI    DC       Bowler     380     157

# %%
df[df.columns[2:8]][10:21]
# Out:
#     AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS
# 10    2      WI   MI+   Allrounder    2200      86
# 11    3      WI   RCB      Batsman    9918       9
# 12    1     IND  KXIP   Allrounder       5       3
# 13    2      SA   DD+    W. Keeper    5457       2
# 14    2     IND   MI+      Batsman       0       0
# 15    2     IND   CSK    W. Keeper    3509       0
# 16    2      SL   DD+   Allrounder    4722      32
# 17    2     IND  KKR+       Bowler       0       0
# 18    3     IND  RCB+      Batsman   13288       1
# 19    2      SA   MI+      Batsman     654      11
# 20    2      WI    DC       Bowler     380     157

# %%
print(list(df['COUNTRY']))
# Out:
# ['SA', 'BAN', 'IND', 'IND', 'IND', 'AUS', 'IND', 'AUS', 'SA', 'SA', 'WI', 'WI', 'IND', 'SA', 'IND', 'IND', 'SL', 'IND', 'IND', 'SA', 'WI', 'SL', 'NZ', 'ENG', 'IND', 'IND', 'WI', 'SA', 'AUS', 'IND', 'IND', 'AUS', 'AUS', 'SA', 'AUS', 'AUS', 'AUS', 'AUS', 'AUS', 'IND', 'IND', 'SL', 'SL', 'IND', 'SA', 'PAK', 'IND', 'IND', 'IND', 'AUS', 'IND', 'IND', 'IND', 'SA', 'IND', 'AUS', 'SL', 'SL', 'ENG', 'SL', 'NZ', 'AUS', 'AUS', 'PAK', 'IND', 'IND', 'PAK', 'SA', 'SA', 'SL', 'AUS', 'IND', 'IND', 'AUS', 'SA', 'IND', 'IND', 'NZ', 'IND', 'IND', 'IND', 'IND', 'IND', 'ENG', 'SA', 'AUS', 'AUS', 'IND', 'IND', 'NZ', 'IND', 'SL', 'WI', 'IND', 'PAK', 'IND', 'IND', 'IND', 'PAK', 'PAK', 'SL', 'IND', 'WI', 'SA', 'PAK', 'IND', 'SA', 'NZ', 'AUS', 'ZIM', 'NZ', 'IND', 'IND', 'IND', 'IND', 'PAK', 'IND', 'SL', 'SA', 'IND', 'NZ', 'IND', 'AUS', 'AUS', 'AUS', 'IND', 'PAK', 'IND', 'IND', 'SL']

# %%
df.iloc[:,4]
# Out:
# 0       KXIP
# 1        RCB
# 2        KKR
# 3        CSK
# 4        CSK
#        ...
# 125       DC
# 126       RR
# 127    KXIP+
# 128      MI+
# 129       DC
# Name: TEAM, Length: 130, dtype: object

# %%
l=list(df['COUNTRY'].values)
l
# Out:
# ['SA',
#  'BAN',
#  'IND',
#  'IND',
#  'IND',
#  'AUS',
#  'IND',
#  'AUS',
#  'SA',
#  'SA',
#  'WI',
#  'WI',
#  'IND',
#  'SA',
#  'IND',
#  'IND',
#  'SL',
#  'IND',
#  'IND',
#  'SA',
#  'WI',
#  'SL',
#  'NZ',
#  'ENG',
#  'IND',
#  'IND',
#  'WI',
#  'SA',
#  'AUS',
#  'IND',
#  'IND',
#  'AUS',
#  'AUS',
#  'SA',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'IND',
#  'IND',
#  'SL',
#  'SL',
#  'IND',
#  'SA',
#  'PAK',
#  'IND',
#  'IND',
#  'IND',
#  'AUS',
#  'IND',
#  'IND',
#  'IND',
#  'SA',
#  'IND',
#  'AUS',
#  'SL',
#  'SL',
#  'ENG',
#  'SL',
#  'NZ',
#  'AUS',
#  'AUS',
#  'PAK',
#  'IND',
#  'IND',
#  'PAK',
#  'SA',
#  'SA',
#  'SL',
#  'AUS',
#  'IND',
#  'IND',
#  'AUS',
#  'SA',
#  'IND',
#  'IND',
#  'NZ',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'IND',
#  'ENG',
#  'SA',
#  'AUS',
#  'AUS',
#  'IND',
#  'IND',
#  'NZ',
#  'IND',
#  'SL',
#  'WI',
#  'IND',
#  'PAK',
#  'IND',
#  'IND',
#  'IND',
#  'PAK',
#  'PAK',
#  'SL',
#  'IND',
#  'WI',
# ...

# %%
print(country)
for i in set(l):
    print(i,l.count(i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [37], line 1
# ----> 1 print(country)
#       2 for i in set(l):
#       3     print(i,l.count(i))
#
# NameError: name 'country' is not defined

# %%
df.value_counts('COUNTRY')*100/130
# Out:
# COUNTRY
# IND    40.769231
# AUS    16.923077
# SA     12.307692
# SL      9.230769
# PAK     6.923077
# NZ      5.384615
# WI      4.615385
# ENG     2.307692
# BAN     0.769231
# ZIM     0.769231
# dtype: float64

# %%
df.value_counts('COUNTRY',normalize=True)*100
# Out:
# COUNTRY
# IND    40.769231
# AUS    16.923077
# SA     12.307692
# SL      9.230769
# PAK     6.923077
# NZ      5.384615
# WI      4.615385
# ENG     2.307692
# BAN     0.769231
# ZIM     0.769231
# dtype: float64

# %%
df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df['BASE PRICE'].sort_values('SOLD PRICE',ascending=False)+df['SOLD PRICE'].sort_values('SOLD PRICE',ascending=False)
# Out:
# C:\Users\JOYDEEP KUNDU\AppData\Local\Temp\ipykernel_16956\815318153.py:1: FutureWarning: In a future version of pandas all arguments of Series.sort_values will be keyword-only.
#   df['BASE PRICE'].sort_values('SOLD PRICE',ascending=False)+df['SOLD PRICE'].sort_values('SOLD PRICE',ascending=False)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     553 try:
# --> 554     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555 except KeyError:
#
# KeyError: 'SOLD PRICE'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In [75], line 1
# ...
